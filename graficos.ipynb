# %% [markdown]
# # Dashboard Covid-19 em 2023

# %% [markdown]
# Importação das biliotecas

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ###### Leitura do Dataset Covid-19

# %%
df = pd.read_csv('covidbr2023.csv',delimiter=';', skiprows=0, low_memory=False)

# %%
df
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 786655  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 786656  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 786657  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 786658  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 786659  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786660 entries, 0 to 786659
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  786660 non-null  object
#  1   estado                  786520 non-null  object
#  2   municipio               779800 non-null  object
#  3   coduf                   786660 non-null  int64
#  4   codmun                  782740 non-null  float64
#  5   codRegiaoSaude          779800 non-null  float64
#  6   nomeRegiaoSaude         779800 non-null  object
#  7   data                    786660 non-null  object
#  8   semanaEpi               786660 non-null  int64
#  9   populacaoTCU2019        783720 non-null  float64
#  10  casosAcumulado          786660 non-null  int64
#  11  casosNovos              786660 non-null  int64
#  12  obitosAcumulado         786660 non-null  int64
#  13  obitosNovos             786660 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semanaEpi', 'populacaoTCU2019',
#        'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos',
#        'Recuperadosnovos', 'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
df1 = df.groupby(['regiao', 'estado'])['casosNovos'].sum().reset_index()

# %%
df1
# Out:
#           regiao estado  casosNovos
# 0   Centro-Oeste     DF       38986
# 1   Centro-Oeste     GO      216254
# 2   Centro-Oeste     MS       38754
# 3   Centro-Oeste     MT       49432
# 4       Nordeste     AL        8408
# 5       Nordeste     BA       63696
# 6       Nordeste     CE       65610
# 7       Nordeste     MA       14782
# 8       Nordeste     PB       19412
# 9       Nordeste     PE      108980
# 10      Nordeste     PI       33942
# 11      Nordeste     RN       13898
# 12      Nordeste     SE        7290
# 13         Norte     AC        9596
# 14         Norte     AM       23576
# 15         Norte     AP        7054
# 16         Norte     PA       38128
# 17         Norte     RO       27356
# 18         Norte     RR        7380
# 19         Norte     TO       19212
# 20       Sudeste     ES       49984
# 21       Sudeste     MG      260594
# 22       Sudeste     RJ      208980
# 23       Sudeste     SP      588104
# 24           Sul     PR      158116
# ...
